# %%
"""
ATE-252
Pandas overview and data manipulation with lite
crash data set.
"""

# %%
## need numpy to work with pandas
import numpy as np
import pandas as pd

"""
This portion is in-class work
"""

## you don't need the csv library because pandas 
## has one
crash_data = pd.read_csv('crashtest_lite.csv')

## print it out to make sure it works and 
## examine data
#print(crash_data.dtypes)

## each column is a unique pandas series object
## can be checked with type()
#counties = crash_data['County Name']
#type(counties)

## Basic analytics on the column. 
## Here count unique values in series
#counties.value_counts()

## If you run type() pandas will return a series
#type(counties.value_counts())

## You can use describe() to pull basic 
## stats on a numerical column

## subset to tinker with
incidents = crash_data[['Municipality Name', 
                        'Crash Year', 
                        'Vehicle Count', 
                        'Injury', 'Person Count']]

person_count = incidents['Person Count']
#vehicle_count.describe()
#incidents.describe()

for rows in incidents['Crash Year']:
    rows = str(rows)
    
#years = incidents['Crash Year']

#print(years.dtypes)

incidents.plot.scatter(x='Person Count', 
                       y='Vehicle Count')

#incidents.plot.scatter(x='Crash Year',
#                      y='Person Count')

#person_count.plot.hist()
#incidents.describe()
#municipalities = incidents['Municipality Name']
#municipalities.value_counts()

# %%
"""
This portion is experimenting with the 
trimmed data set to be used in capstone project
"""
## test to see how well jupyter notebooks handles 413K rows
## Result : Not bad!

unbelted_data = pd.read_csv('crash_data_filtered_by_unbelted.csv')
unbelted_data
# Out:
#         Crash Record Number  County Code   County Name  Municipality Code  \
# 0                2017092445           62    Washington              62228
# 1                2017101502           33     Jefferson              33208
# 2                2018002940           18       Clinton              18405
# 3                2017076390           59         Union              59210
# 4                2017028935           67  Philadelphia              67301
# ...                     ...          ...           ...                ...
# 413675           2000120623           66          York              66301
# 413676           2003004935            6         Berks               6242
# 413677           2012076484           62    Washington              62419
# 413678           2002239561            9         Bucks               9227
# 413679           2005184163           30        Greene              30205
#
#             Municipality Name  District Code  District Name  \
# ...
